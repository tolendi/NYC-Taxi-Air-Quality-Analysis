# %%
import requests
from pathlib import Path

url = "https://d37ci6vzurychx.cloudfront.net/misc/taxi_zone_lookup.csv"

bronze_path = Path("/lakehouse/default/Files/bronze/taxi")
bronze_path.mkdir(parents=True, exist_ok=True)

file_path = bronze_path / "taxi_zone_lookup.csv"

response = requests.get(url)
response.raise_for_status()

with open(file_path, "wb") as f:
    f.write(response.content)

file_path
# Out:
# StatementMeta(, 8317ef89-ccf6-4a51-8b39-e75d6df452c9, 3, Finished, Available, Finished)
# PosixPath('/lakehouse/default/Files/bronze/taxi/taxi_zone_lookup.csv')

# %%
from pyspark.sql import functions as F

df_zone_raw = (
    spark.read
    .option("header", True)
    .csv("Files/bronze/taxi/taxi_zone_lookup.csv")
)

df_zone_raw.show(5)
df_zone_raw.printSchema()
# Out:
# StatementMeta(, 8317ef89-ccf6-4a51-8b39-e75d6df452c9, 4, Finished, Available, Finished)
# +----------+-------------+--------------------+------------+
# |LocationID|      Borough|                Zone|service_zone|
# +----------+-------------+--------------------+------------+
# |         1|          EWR|      Newark Airport|         EWR|
# |         2|       Queens|         Jamaica Bay|   Boro Zone|
# |         3|        Bronx|Allerton/Pelham G...|   Boro Zone|
# |         4|    Manhattan|       Alphabet City| Yellow Zone|
# |         5|Staten Island|       Arden Heights|   Boro Zone|
# +----------+-------------+--------------------+------------+
# only showing top 5 rows
#
# root
#  |-- LocationID: string (nullable = true)
#  |-- Borough: string (nullable = true)
#  |-- Zone: string (nullable = true)
#  |-- service_zone: string (nullable = true)

# %%
df_dim_zone = (
    df_zone_raw
    .select(
        F.col("LocationID").cast("int").alias("zone_id"),
        F.col("Borough").alias("borough"),
        F.col("Zone").alias("zone_name"),
        F.col("service_zone")
    )
    .dropDuplicates(["zone_id"])
)
# Out:
# StatementMeta(, 8317ef89-ccf6-4a51-8b39-e75d6df452c9, 5, Finished, Available, Finished)

# %%
df_dim_zone.count()
df_dim_zone.show(5, truncate=False)
# Out:
# StatementMeta(, 8317ef89-ccf6-4a51-8b39-e75d6df452c9, 6, Finished, Available, Finished)
# +-------+-------------+-----------------------+------------+
# |zone_id|borough      |zone_name              |service_zone|
# +-------+-------------+-----------------------+------------+
# |1      |EWR          |Newark Airport         |EWR         |
# |2      |Queens       |Jamaica Bay            |Boro Zone   |
# |3      |Bronx        |Allerton/Pelham Gardens|Boro Zone   |
# |4      |Manhattan    |Alphabet City          |Yellow Zone |
# |5      |Staten Island|Arden Heights          |Boro Zone   |
# +-------+-------------+-----------------------+------------+
# only showing top 5 rows

# %%
dim_zone_norm = (
    df_dim_zone
    .withColumn(
        "zone_name_norm",
        F.lower(F.trim(F.col("zone_name")))
    )
    .select("zone_id", "zone_name_norm", "zone_name", "borough")
)
dim_zone_norm.show(5, truncate=False)
# Out:
# StatementMeta(, 8317ef89-ccf6-4a51-8b39-e75d6df452c9, 9, Finished, Available, Finished)
# +-------+-----------------------+-----------------------+-------------+
# |zone_id|zone_name_norm         |zone_name              |borough      |
# +-------+-----------------------+-----------------------+-------------+
# |1      |newark airport         |Newark Airport         |EWR          |
# |2      |jamaica bay            |Jamaica Bay            |Queens       |
# |3      |allerton/pelham gardens|Allerton/Pelham Gardens|Bronx        |
# |4      |alphabet city          |Alphabet City          |Manhattan    |
# |5      |arden heights          |Arden Heights          |Staten Island|
# +-------+-----------------------+-----------------------+-------------+
# only showing top 5 rows

# %%
df_locations_silver = spark.read.table("df_locations_silver")
# Out:
# StatementMeta(, 8317ef89-ccf6-4a51-8b39-e75d6df452c9, 12, Finished, Available, Finished)

# %%
air_zone_map = (
    df_locations_silver
    .join(
        dim_zone_norm,
        df_locations_silver.location_name_norm == dim_zone_norm.zone_name_norm,
        "left"
    )
)
# Out:
# StatementMeta(, 8317ef89-ccf6-4a51-8b39-e75d6df452c9, 13, Finished, Available, Finished)

# %%
air_zone_map.select(
    "location_id",
    "name",
    "zone_name",
    "zone_id"
).show(50, truncate=False)
# Out:
# StatementMeta(, 8317ef89-ccf6-4a51-8b39-e75d6df452c9, 14, Finished, Available, Finished)
# +-----------+--------------------------------------------------+-------------+-------+
# |location_id|name                                              |zone_name    |zone_id|
# +-----------+--------------------------------------------------+-------------+-------+
# |384        |CCNY                                              |NULL         |NULL   |
# |386        |Susan Wagner                                      |NULL         |NULL   |
# |625        |Manhattan/IS143                                   |NULL         |NULL   |
# |626        |Bronx - IS52                                      |NULL         |NULL   |
# |628        |Maspeth                                           |Maspeth      |157    |
# |631        |Queens                                            |NULL         |NULL   |
# |642        |PS 19                                             |NULL         |NULL   |
# |648        |Bklyn - PS 314                                    |NULL         |NULL   |
# |662        |Division Street                                   |NULL         |NULL   |
# |664        |Bklyn - PS274                                     |NULL         |NULL   |
# |665        |Bronx - IS74                                      |NULL         |NULL   |
# |666        |Pfizer Lab                                        |NULL         |NULL   |
# |853        |East Orange                                       |NULL         |NULL   |
# |857        |Fort Lee Near Road                                |NULL         |NULL   |
# |928        |Jersey City FH                                    |NULL         |NULL   |
# |971        |Elizabeth Trailer                                 |NULL         |NULL   |
# |974        |Newark Firehouse                                  |NULL         |NULL   |
# |984        |Leonia                                            |NULL         |NULL   |
# |1122       |Jersey City                                       |NULL         |NULL   |
# |1496       |Bayonne                                           |NULL         |NULL   |
# |2193       |Elizabeth                                         |NULL         |NULL   |
# |8749       |Queens Near-road                                  |NULL         |NULL   |
# |292229     |Morrisania                                        |NULL         |NULL   |
# |387315     |Union City High Scho                              |NULL         |NULL   |
# |496096     |Port Richmond                                     |Port Richmond|187    |
# |1236043    |Franklin Avenue                                   |NULL         |NULL   |
# |1738519    |Bayside, NY                                       |NULL         |NULL   |
# |1775647    |State Dept of Environmental Conservation          |NULL         |NULL   |
# |1824516    |Bayside, NY                                       |NULL         |NULL   |
# |2153518    |Jersey City Heights                               |NULL         |NULL   |
# |2386747    |Carteret, NJ                                      |NULL         |NULL   |
# |2453305    |State Dept of Environmental Conservation          |NULL         |NULL   |
# |2453313    |State Dept of Environmental Conservation          |NULL         |NULL   |
# |2616564    |7th Ave and W 16th St                             |NULL         |NULL   |
# |2903996    |Win Son                                           |NULL         |NULL   |
# |3041962    |Near Bay 50 St                                    |NULL         |NULL   |
# |3103622    |Montclair, NJ                                     |NULL         |NULL   |
# |3145067    |Metal fence on PS9 back campus [NYC Testbed Pilot]|NULL         |NULL   |
# |3145068    |56th St & Flushing [NYC Testbed Pilot]            |NULL         |NULL   |
# |3145069    |Closest to SA unit on PS9 campus                  |NULL         |NULL   |
# |3145070    | 57th St/Front of School [NYC Testbed Pilot]      |NULL         |NULL   |
# |3145072    |54th St & Flushing [NYC Testbed Pilot]            |NULL         |NULL   |
# |3145073    |56th St & Grand Ave [NYC Testbed Pilot]           |NULL         |NULL   |
# |3145074    | 54th St & Grand Ave [NYC Testbed Pilot]          |NULL         |NULL   |
# |3181018    |Hillcrest, NY                                     |NULL         |NULL   |
# |3305066    |Downtown Montclair                                |NULL         |NULL   |
# |3400913    |DropHome                                          |NULL         |NULL   |
# |3406357    |Bayside, NY 11361                                 |NULL         |NULL   |
# |4419380    |NJBAM Test Weehawken                              |NULL         |NULL   |
# |4727343    |E Houston St between Clinton St & Attorney St     |NULL         |NULL   |
# +-----------+--------------------------------------------------+-------------+-------+
# only showing top 50 rows

# %%
(
    df_dim_zone
    .write
    .mode("overwrite")
    .format("delta")
    .saveAsTable("dbo.dim_zone")
)
# Out:
# StatementMeta(, 6b0bbe09-9573-4bdd-b074-1e3e4abb6f6a, 7, Finished, Available, Finished)

# %%
spark.sql("""
SELECT
    COUNT(*) AS trips,
    COUNT(zone_id) AS zones
FROM dbo.silver_taxi_trips t
LEFT JOIN dbo.dim_zone z
    ON t.PULocationID = z.zone_id;
""").show()
# Out:
# StatementMeta(, 6cdbbf21-4a5e-4814-a9c6-a410a04c6139, 3, Finished, Available, Finished)
# +-------+-------+
# |  trips|  zones|
# +-------+-------+
# |2840785|2840785|
# +-------+-------+
